# %% [markdown]
# ### Q1.
# Open your terminal or command prompt.

# %% [markdown]
# ### Answer:
#
# ![](Screenshot/Assignment_2_Q1.png)

# %% [markdown]
# ###  Q2.
# Navigate to a directory where you want to create a new folder for this assignment using the `cd` command.

# %%
# !cd Desktop/QTM350
# Out:
# 28.02s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# zsh:cd:1: no such file or directory: Desktop/QTM350

# %% [markdown]
# ### Answer:
#
# ![](Screenshot/Assignment_2_Q2.png)

# %% [markdown]
# ### Q3.
# Create a new directory called "cli_assignment" using the `mkdir` command.

# %%
# !mkdir cli_assignment
# Out:
# 170.77s - pydevd: Sending message related to process being replaced timed-out after 5 seconds

# %% [markdown]
# ### Answer:
# ![](Screenshot/Assignment_2_Q3.png)

# %% [markdown]
# ### Q4.
# Change into the "cli_assignment" directory using the `cd` command.

# %%
# !cd cli_assignment

# %% [markdown]
# ### Answer:
# ![](Screenshot/Assignment_2_Q4.png)

# %% [markdown]
# ### Q5a.
# Use the `ls` command to list the contents of the current directory. Take a screenshot of the output.

# %%
# !ls
# Out:
# 414.04s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Assignment_2.ipynb Screenshot

# %% [markdown]
# ### Answer:
# ![](Screenshot/Assignment_2_Q5a.png)

# %% [markdown]
# ### Q5b.
# Create a new file called "README.md" using the `touch` command. Use the `ls` command again to verify that the file was created. Take a screenshot of the output.

# %%
# !touch README.md
# !ls
# Out:
# 527.54s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 532.90s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Assignment_2.ipynb README.md          Screenshot

# %% [markdown]
# ### Answer:
# ![](Screenshot/Assignment_2_Q5b.png)

# %% [markdown]
# ### Q5c.
# Use the `echo` command to append the text "# CLI Assignment" to the "README.md" file. Use the `cat` command to display the contents of the file. Take a screenshot of the output.

# %%
# !echo "# CLI Assignment" >> README.md
# !cat README.md
# Out:
# 642.42s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 647.75s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# # CLI Assignment
# # CLI Assignment

# %% [markdown]
# ### Answer:
# ![](Screenshot/Assignment_2_Q5c.png)

# %% [markdown]
# ### Q5d.
# Create a new directory called "data" inside the "cli_assignment" directory using the `mkdir` command. Use the `ls` command with the `-l` flag to display the contents of the "cli_assignment" directory in long format. Take a screenshot of the output.

# %%
# !mkdir data
# !ls -l

# %% [markdown]
# ### Answer:
# ![](Screenshot/Assignment_2_Q5d.png)

# %% [markdown]
# ### Q5e.
#
# Use the `man` command to display the manual page for the `ls` command. Scroll through the manual page and find the flag that allows you to display hidden files. Use the `ls` command with this flag to display all files, including hidden files, in the current directory. Take a screenshot of the output.

# %%
# !man ls 
# !ls -a
# Out:
# 1033.12s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Unknown locale, assuming C
# LS(1)                       General Commands Manual                      LS(1)
#
# NAME
#      ls – list directory contents
#
# SYNOPSIS
#      ls [-@ABCFGHILOPRSTUWabcdefghiklmnopqrstuvwxy1%,] [--color=when]
#         [-D format] [file ...]
#
# DESCRIPTION
#      For each operand that names a file of a type other than directory, ls
#      displays its name as well as any requested, associated information.  For
#      each operand that names a file of type directory, ls displays the names
#      of files contained within that directory, as well as any requested,
#      associated information.
#
#      If no operands are given, the contents of the current directory are
#      displayed.  If more than one operand is given, non-directory operands are
#      displayed first; directory and non-directory operands are sorted
# ...

# %% [markdown]
# ### Answer:
# ![](Screenshot/Assignment_2_Q5e.png)
